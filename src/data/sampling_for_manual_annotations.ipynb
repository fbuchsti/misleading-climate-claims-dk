# %% [markdown]
# # SAMPLE SUBSET FOR EXPERT ANNOTATIONS

# %%
import pandas as pd

# %%
# load data 
df = pd.read_parquet("data/processed/sample_llm_annotation.parquet")

# %%
# sample subset for expert annotation
sample_df = df.sample(n=500, random_state=42)

# %%
sample_df.to_excel("data/processed/sample_manual_annotation.xlsx", index=False)
